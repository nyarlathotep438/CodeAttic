# %%
# Suppose we have a dataset that represents number of siblings.
data = [46,50,46,52,46,55,58,54,60,0,46,62,0,0,54,59,57,56]

# In this data set we want to find outliers. Firstly we calculate Z-Score for them.

import numpy as np
mean = np.mean(data) # Find mean
std = np.std(data)   # Find standart deviation

upper_limit = 2
lower_limit = -2
outlier = []

for i in data:
  # Find Z-Score
  z = (i-mean)/std
  print(f'Z-Score of {i} = {z}')
  # Check z value is within or not in our range
  if (lower_limit > z) or (z > upper_limit):
      outlier.append(i)

print('Outlier in dataset is', outlier)
# Out:
# Z-Score of 46 = 0.07321914426502024
# Z-Score of 50 = 0.26847019563840757
# Z-Score of 46 = 0.07321914426502024
# Z-Score of 52 = 0.3660957213251012
# Z-Score of 46 = 0.07321914426502024
# Z-Score of 55 = 0.5125340098551416
# Z-Score of 58 = 0.6589722983851821
# Z-Score of 54 = 0.46372124701179485
# Z-Score of 60 = 0.7565978240718758
# Z-Score of 0 = -2.172167946528934
# Z-Score of 46 = 0.07321914426502024
# Z-Score of 62 = 0.8542233497585695
# Z-Score of 0 = -2.172167946528934
# Z-Score of 0 = -2.172167946528934
# Z-Score of 54 = 0.46372124701179485
# Z-Score of 59 = 0.707785061228529
# Z-Score of 57 = 0.6101595355418353
# Z-Score of 56 = 0.5613467726984885
# Outlier in dataset is [0, 0, 0]
