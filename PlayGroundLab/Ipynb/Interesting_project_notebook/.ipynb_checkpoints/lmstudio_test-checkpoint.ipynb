# %%
import lmstudio as lms

# %%
##### import lmstudio as lms

model = lms.llm("qwen/qwen3.6-35b-a3b")
result = model.respond("如何进行严谨的数学证明?")

print(result)
# Out:
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user asks "如何进行严谨的数学证明?" (How to conduct rigorous mathematical proofs?) in Chinese. This is a broad, foundational question about mathematical rigor, proof techniques, and the process of constructing valid arguments.
#
# 2.  **Identify Key Components of Rigorous Mathematical Proofs:**
#    - Definition of rigor in mathematics
#    - Logical structure (premises, definitions, axioms, lemmas, theorems, conclusions)
#    - Proof techniques (direct, contradiction, induction, construction, cases, etc.)
#    - Precision in language and notation
#    - Verification and peer review
#    - Common pitfalls to avoid
#    - Steps/process for writing a proof
#    - Resources for learning
#
# 3.  **Structure the Response (in Chinese):**
#    I'll organize it logically:
#    - 引言：什么是严谨的数学证明
#    - 核心原则
#    - 常用证明方法
#    - 写作步骤与规范
#    - 常见错误与避坑指南
#    - 学习建议与资源
#    - 结语
#
# 4.  **Draft Content (Mental Refinement in Chinese):**
#
# ...
