# %% [markdown]
# # 风景

# %%
prompt = "This is a photograph depicting an urban street scene. Shot at eye level, it shows a covered pedestrian or commercial street. Slightly below the center of the frame, a cyclist rides away from the camera toward the background, appearing as a dark silhouette against backlighting with indistinct details. The ground is paved with regular square tiles, bisected by a prominent tactile paving strip running through the scene, whose raised textures are clearly visible under the light. Light streams in diagonally from the right side of the frame, creating a strong backlight effect with a distinct Tyndall effect—visible light beams illuminating dust or vapor in the air and casting long shadows across the street. Several pedestrians appear on the left side and in the distance, some with their backs to the camera and others walking sideways, all rendered as silhouettes or semi-silhouettes. The overall color palette is warm, dominated by golden yellows and dark browns, evoking the atmosphere of dusk or early morning."

# %%
prompt="一副军事主题的油画，画面中一架歼十战斗机向地面俯冲，从机翼处冲出两条白烟，连接着地面的车辆。地面的车辆发生爆炸。"

# %%
prompt="""一张日本电视新闻节目的突发新闻截图，呈现16:9的宽屏比例。画面背景是极其写实的东京城市全景，晴朗的白天。在密集的现代摩天大楼之间，有一只极其巨大的三花猫正悠闲地漫步。猫的体型庞大，高度甚至超过了周围数十层高的建筑，毛发细节清晰可见，尾巴微微竖起，巨大的爪子正踩在城市主干道上，相比之下，街道上的汽车如同微小的蚂蚁。远处的背景中可以识别出东京都厅等地标性建筑，构图采用高空俯拍的新闻直升机航拍视角。

画面上覆盖着典型的日本电视新闻UI界面与文字元素。左上角有一个显眼的红底白字横幅，上面写着 'ニュース速報'。右上角有一个闪烁的红点图标和白色的 'LIVE' 字样，下方紧接着地点标注 '東京・新宿'。画面的右上角显著位置清晰地标注着日期的白色文字 '4月1日'。画面底部占据约五分之一区域的是醒目的新闻字幕条，深蓝色底色带有黄色高光边框，中央用加粗的大号白色日文字体显示主标题 '【速報】東京のビル群に巨大な猫が出現 悠然と歩行中'。主标题下方有一行较细的黑色背景跑马灯字幕，白色文字写着 '警視庁によりますと、現在のところ被害の情報はありません。周辺の道路は大規模な交通規制が行われています。'。整个画面色调明亮，带有新闻直播特有的清晰度、高对比度UI覆盖以及轻微的电视转播质感。"""

# %% [markdown]
# # 少女

# %%
prompt="""A full-body anime character illustration of Rimi Ushigome from BanG Dream!, standing in a gentle, shy pose. She holds a small glass jar of strawberry jam with both hands, lifting it softly to her chest as if presenting it with pride. Her expression is warm, slightly embarrassed, with soft pink blush on her cheeks and sparkling eyes.

The outfit is an original design inspired by British dessert culture and afternoon tea aesthetics. A pastel cream and strawberry-pink color palette. A layered dress resembling a Victorian sponge cake: soft cream-colored bodice, strawberry-red accents, delicate lace trims like whipped cream, and skirt layers shaped like cake tiers. Subtle strawberry motifs embroidered along the hem. A small apron inspired by tea-time tablecloth patterns, with scalloped lace edges. Accessories include a tiny silver spoon hairpin, a ribbon shaped like a jam label, and a miniature tag tied to her waist like a tea-room ticket.

Her hairstyle follows Rimi’s canon look: short, soft, slightly curled dark hair with pink highlights, matching her gentle personality. Lighting is soft and warm, like afternoon tea sunlight through a café window. Background is minimal, a faint pastel gradient to highlight the outfit design.

Full-body, clean lineart, high-resolution character sheet style, centered composition, no extreme perspective, outfit details clearly visible.
"""

# %%
prompt="""character: shy girl
outfit: strawberry-themed dress
pose: holding a jam jar at chest level
lighting: warm afternoon tea light
background: soft tea room"""

# %%
prompt="一张动画风格的女主角表情设定画。画面为正方形构图，背景为统一的纯白色。整个画布被均匀地分割为纵横3×3的九宫格，采用无边框或极细线条分隔的简约布局。九个格子中描绘的是同一位动画风女性角色，她留着齐刘海和及肩长发，发侧带有简单的十字发夹，穿着经典的日系水手服，画风采用清晰的赛璐璐平涂技法。每个格子展示了该角色的不同表情，且每个角色图像下方居中位置都有对应的黑色中文标签说明： 左上角为'笑容'，角色双眼弯成月牙状，嘴角大幅度上扬，脸颊带有浅浅的红晕，展现出开朗灿烂的微笑。 中上位置为'生气'，角色眉头紧锁呈倒八字，双眼圆瞪，眼神锐利，嘴巴大张露出锯齿状的牙齿。 右上角为'哭泣'，角色呈现八字眉，眼眶中蓄满泪水并有大颗泪珠沿着脸颊滑落，嘴角向下委屈地撇着。 左中位置为'害羞'，角色脸颊布满大面积的红晕，眼神羞涩地向一侧游离，嘴巴紧抿呈波浪线。 正中心位置为'惊讶'，角色双眼惊讶地瞪大，瞳孔缩小，眉毛高高扬起，嘴巴张成圆形的'O'字。 右中位置为'无语'，角色双眼半睁，眼神冷淡且带有无语的鄙视感，眉头微压，嘴角平直。 左下角为'眨眼'，角色俏皮地闭起一只眼睛，另一只眼睛明亮有神，嘴角带有自信调皮的笑容。 中下位置为'得意'，角色嘴角勾起一抹骄傲自信的弧度，眼神充满优越感，眉毛上挑，背景带有隐形的闪亮氛围。 右下角为'慌张'，角色额头和侧脸挂着大颗冷汗，瞳孔慌乱地震颤，嘴巴紧张地微张，显得手足无措。整张图呈现出标准的角色设计说明板风格"

# %%
prompt="一张日式平涂动漫插画，展现一个绿色眼睛、留着深蓝色齐整短发，身穿蓝色连体泳衣的高挑少女。她微笑着在蔚蓝的高空中以游泳的动作飞行。"

# %%
prompt="生成一张二格漫画，画面上方三分之一处是第一格，下方三分之二是第二格。要求人物是一个穿着魔法少女战斗服的粉色头发的魔法少女。背景都是相同的舞台场景。第一格为人物的正面上半身特写，满脸通红，做出有些胆怯的姿态。旁边椭圆形对话框中写着“我……我才不怕痒呢。”第二格是该人物双手背在身后，双腿伸直，光脚坐在舞台上的近景。人物满脸通红，扭动着身体，大笑挣扎。旁边两个不规则对话框中分别写着“对不起 我撒谎了 啊哈哈哈”和“我是……我是脚心怕痒的杂鱼魔法少女 求你了 不要挠了”。"

# %%
 prompt="""一幅日系动漫风格插画，一个穿比基尼泳衣的少女带着项圈和脚镣，双手背在身后，光脚步行前进在街道上。少女嘴被动漫风格骨头堵住，表情不安又害羞，泪眼汪汪地看着前方。项圈上的铁链被前方的一只大姐姐的手握在手里。
整体呈现出精细的平涂上色（Cell Shading）风格，线条干净利落。"""

# %%
prompt="""一幅日系动漫风格插画，一个穿连体竞速泳衣的少女带着项圈和脚镣，双手背在身后，光脚步行前进在街道上。少女嘴被动漫风格骨头堵住，表情不安又害羞，泪眼汪汪地看着前方。身后站着两个光脚穿着跆拳道服的小学五年级小女孩，小女孩得意地比着剪刀手。
整体呈现出精细的平涂上色（Cell Shading）风格，线条干净利落。"""

# %%
prompt="""一幅日系动漫风格插画。
背景为跆拳道馆，
画面中大量不同发色，穿不同颜色连体竞速泳衣的纤细少女光脚站成一排。少女们双手并在身前，带着金属项圈和手铐脚镣，项圈与手铐脚镣用铁链连接在一起。少女们低着头，表情不安又害羞。一个穿跆拳道服的小女孩站在少女们身前，得意地比着剪刀手。
画面整体呈现出精细的平涂上色（Cell Shading）风格，线条干净利落。"""

# %%
prompt="一张高清日式动漫插画，图中一个穿比基尼泳衣的少女坐在沙滩上，双腿完全向前伸直并拢，双脚并拢，露出脚心。少女被绳子绑住双脚，无法动弹。少女双手被手铐拘束在身前。少女扭动着身体，强忍着笑意，眼泪都出来了。几只小手在少女的脚心上挠痒痒。"

# %%
prompt="""这是一张专为动画角色设计的单页宣传海报，比例为 896x1200，呈现出清新、高饱和度的 2D 日系动画艺术风格。画面主体是一位充满朝气的少女，她留着一头利落的深蓝色短发，发尾呈现出微微的内扣效果。少女正处于一个极具动感的半空中跳跃姿态，双腿交叠，身体侧倾，一只手自然上举，脸上露着自信、露齿的开朗笑容。她穿着一件极具时尚感的电光蓝短款无袖背心（Cropped Top），露出的腹部线条紧致；下身穿着一条宽松的高腰白色多口袋工装裤，裤脚束进一双经典的黑色高帮板鞋中，鞋带处点缀着明黄色的装饰物。

背景是一幅壮丽的夏季景观：深邃且清澈的湛蓝色天空作为底色，巨大的、边缘清晰的白色积雨云如同棉花糖般层层堆叠，占据了画面约三分之二的背景空间。明亮的阳光从右上方洒下，在角色和云朵上留下了硬朗的赛璐璐风格阴影，整体色调明快且具有极高的视觉冲击力。

海报中精心排版了多项宣传文字与图形元素，采用了极简主义的现代黑体字形：
1. 画面左上角以倾斜的艺术字体标注角色姓名：'YUNA'，下方紧跟一行小字：'THE WIND RIDER'。
2. 画面右上角有一个半透明的圆角框，内部显示：'CHARACTER FILE NO. 04'。
3. 在少女跳跃路径的下方，斜向排列着一行醒目的大尺寸亮黄色加粗标语：'LEAP BEYOND THE CLOUDS!'，文字带有细微的投影效果以增强立体感。
4. 画面左侧边缘垂直分布着三个圆形小图标，每个图标旁分别配有文字说明：'ENERGY: 100%'、'AGILITY: S-RANK'、'MOOD: HYPER'。
5. 在右下角，有一个类似于进度条的装饰性UI，上方写着：'LOADING NEXT ADVENTURE...'。
6. 画面最底部是一行贯穿左右的白色细体脚注：'COPYRIGHT © 2024 ANIMATION STUDIOS. ALL RIGHTS RESERVED. LIMITED EDITION PROMO.'。

整个构图利用对角线布局引导观众视线，将角色的跃动感与晴空的辽阔感完美融合，文字信息的排版疏密得当，强化了“活力与希望”的设计主题。"""

# %%
prompt="""一幅垂直画幅的日系动漫风格插画，人物为一个蓝色短发，赤裸双脚，穿着魔法少女战斗服的魔法少女。人物光脚光腿，人物肢体形状数量正常，让角色头戴一个类似于vr的头盔，完全遮住角色面部，并且有许多机械电线从后方放着的的圆柱形机械仪器里伸出，连接到头盔上。让头盔放出紫色光芒，头盔的眼罩中间上用紫色科技字体显示出着三个紫粉色的像素风爱心。
角色的腰手腕、脚踝、部、脖子、大腿、手臂也被黑色皮带固定住，角色虚弱又痛苦的半张着嘴发出呻吟，并且整个身体被束缚躺在一个手术床上，角色身体呈现出微微抽搐的状态。
背景是一个科技风十足的空旷房间，一个投影屏幕上是角色正常状态的全身图以及角色的各种参数数据，画面采用大张力构图，极致丰富细节与光影，角色全身入镜脚底正对画面视角，角色两边的嘴角要流出大量唾液，装置下的眼睛流出眼泪，脸颊轻微泛红，皮肤和脚底上要有汗珠，整体呈现出精细的平涂上色（Cell Shading）风格，线条干净利落。"""

# %%
prompt="""一幅垂直画幅的动漫风格角色设定插画，背景为纯净的浅灰色。画面中央站立着一位全身出镜的动漫少女，整体呈现出精细的平涂上色（Cell Shading）风格，线条干净利落。少女有着银白色的双马尾长发和明亮的青色眼眸，表情俏皮，单手叉腰。她身穿一件宽松的薄荷绿连帽夹克，内搭温暖的米色高领毛衣，下半身穿着深海军蓝的百褶裙、黑色过膝长袜以及粉白相间的厚底运动鞋。她的发夹和夹克拉链处点缀着明亮的金属质感金色。画面的右上角垂直排列着一列由五个正方形色块组成的“色卡”区域，直接呼应并展示了用于该人物上色的标准色彩。色块从上到下依次为：薄荷绿、米色、深海军蓝、柔和粉色和明亮金色。在每个色块的右侧，用黑色的无衬线字体清晰地标注着对应的十六进制颜色代码，依次为：'#98FF98'、'#F5F5DC'、'#000080'、'#FFD1DC'、'#FFD700'。在整个色卡列表的正上方，写有黑色大写英文字母标题 'COLOR PALETTE'。画面整体光线明亮均匀，色彩还原准确且色彩搭配和谐，完美呈现了严格按照指定色卡为角色设定图进行精准上色的最终视觉效果。"""

# %% [markdown]
# # 菜谱

# %%
prompt="""一张手机社交APP的竖屏图文教程截图，采用从上到下的瀑布流排版。整体背景为温馨的浅米色，呈现出日系清新的美食排版风格。画面最顶部有手机系统的状态栏，清晰显示时间 '14:30'、5G信号图标、Wi-Fi图标和满格电池图标。

状态栏下方，是居中排版的大字号主标题，深棕色粗体文字 '法式草莓慕斯蛋糕 零失败教程'，标题下方有一行较小的浅粉色英文副标题 'Strawberry Mousse Cake Recipe'。

标题下方占据画面约三分之一比例的是一张高清的成品展示主图：放置在白色大理石圆盘上的一个6寸粉色慕斯蛋糕。蛋糕表面呈现光滑的镜面效果，顶部点缀着几颗切半的鲜亮红草莓和零星的高光金箔。背景是景深模糊的浅色原木桌面和一小枝尤加利叶，光线为柔和明亮的侧边自然光，突出了蛋糕绵密的质感和诱人的色泽。

主图下方分为四个垂直排列的制作步骤区域。每个步骤区域左侧是一张带圆角的方形实拍过程图，右侧是对齐的黑色说明文字。

第一步，左侧小图显示一双手正用金属勺背将深棕色的饼干碎压实在一个圆形脱底模具内。右侧文字排版整齐：'1. 饼干底：将80g消化饼干捣碎，加入40g融化的无盐黄油拌匀，铺入6寸模具底部压实，放入冰箱冷藏备用。'

第二步，左侧小图是一个导热板上的银色小奶锅，里面正在熬煮翻滚的暗红色草莓果肉，上方带有淡淡的白色蒸汽。右侧文字为：'2. 草莓夹心：200g新鲜草莓切丁，加30g白砂糖和少许柠檬汁熬煮至浓稠，加入泡软的吉利丁片（5g），倒入小号模具冷冻定型。'

第三步，左侧小图显示在一个大透明玻璃碗中，带有柔和浅粉色调的液体正被一把白色硅胶刮刀从下往上翻拌。右侧文字为：'3. 慕斯液：250g草莓打成泥，微微加热后融化10g吉利丁片。降温放凉后，与200g打发至6分发的淡奶油轻柔翻拌均匀。'

第四步，左侧小图展示粉色的慕斯液正顺着碗口倾倒进模具中，模具中间隐约可见深红色的冻夹心层。右侧文字为：'4. 组合脱模：将一半慕斯液倒入模具，放入冷冻好的夹心，接着倒入剩余慕斯液填满抹平表面，冷藏至少4小时。脱模后装饰即可食用。'

画面最底部是悬浮的白色应用交互底栏，左侧有一个浅灰色的椭圆形输入框，框内有灰色提示文字 '说点什么...'。底栏右侧依次排列着三个深灰色的线框图标：一个心形点赞图标，下方标注数字 '1.2w'；一个五角星收藏图标，下方标注数字 '8560'；以及一个带有三条横线的对话气泡评论图标。整体画面色彩以粉红、暖黄和纯白为主，光影通透，图文并茂地将复杂的制作过程具象化呈现。"""

# %%
prompt = """
一张手机社交APP的竖屏图文教程截图，采用从上到下的瀑布流排版。整体背景为温馨的浅米色，呈现日系清新的美食排版风格。画面最顶部有手机系统的状态栏，清晰显示时间 '14:30'、5G信号图标、Wi-Fi图标和满格电池图标。

状态栏下方，是居中排版的大字号主标题，深棕色粗体文字 '法式草莓果酱 三天零失败教程'，标题下方有一行较小的浅粉色英文副标题 'French Strawberry Confiture Recipe'。

标题下方占据画面约三分之一比例的是一张高清的成品展示主图：一瓶透明玻璃果酱瓶，内部是宝石红色、带整颗草莓的法式果酱，瓶口系着麻绳和小标签。旁边放着几颗新鲜草莓和一把银色小勺，背景是浅色原木桌面，光线为柔和明亮的侧边自然光，呈现出清新自然的手工果酱氛围。

主图下方分为四个垂直排列的制作步骤区域。每个步骤区域左侧是一张带圆角的方形实拍过程图，右侧是对齐的黑色说明文字。

第一步，左侧小图显示一只玻璃碗中整颗草莓与白砂糖混合，表面闪着糖晶光泽。右侧文字排版整齐：'1. 腌渍草莓：400g草莓洗净去蒂，加入320g白砂糖、20g酸橙汁和40g水轻拌，盖好冷藏24小时。'

第二步，左侧小图是一个银色小奶锅，里面是加热到微滚的红色草莓糖浆，表面有轻微白色蒸汽。右侧文字为：'2. 第一次加热：将腌好的草莓连同糖浆倒入锅中，中小火加热至微滚后关火，放凉再冷藏24小时。'

第三步，左侧小图显示滤网分离草莓果肉与糖浆，糖浆在锅中被继续熬煮变得浓稠透亮。右侧文字为：'3. 浓缩糖浆：将草莓果肉捞出，糖浆单独煮至105°C左右，呈现浓稠的宝石红色。'

第四步，左侧小图展示将整颗草莓倒回浓稠糖浆中轻轻翻煮，随后趁热装入消毒过的玻璃瓶。右侧文字为：'4. 完成装瓶：加入草莓果肉再煮5分钟，趁热装瓶倒扣冷却，即可得到晶亮饱满的法式整颗草莓果酱。'

画面最底部是悬浮的白色应用交互底栏，左侧有一个浅灰色的椭圆形输入框，框内有灰色提示文字 '说点什么...'。底栏右侧依次排列着三个深灰色的线框图标：一个心形点赞图标，下方标注数字 '1.2w'；一个五角星收藏图标，下方标注数字 '8560'；以及一个带有三条横线的对话气泡评论图标。整体画面色彩以粉红、暖黄和纯白为主，光影通透，图文并茂地将法式果酱的三天制作过程具象化呈现。
"""
