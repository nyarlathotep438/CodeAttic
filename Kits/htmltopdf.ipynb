# %%
import subprocess

WKHTML = r"C:\Program Files\wkhtmltopdf\bin\wkhtmltopdf.exe"

url = input("请输入要转换的网页 URL： ").strip()
output = input("请输入输出 PDF 的完整路径（含文件名）： ").strip()

# subprocess.run 接受列表
cmd = [WKHTML, url, output]

print("\n执行命令：")
print(cmd)

subprocess.run(cmd)
# Out:
# 请输入要转换的网页 URL：  https://wkhtmltopdf.org/
# 请输入输出 PDF 的完整路径（含文件名）：  C:\Users\Admin\Interesting project notebook\3.pdf
# 执行命令：
# ['C:\\Program Files\\wkhtmltopdf\\bin\\wkhtmltopdf.exe', 'https://wkhtmltopdf.org/', 'C:\\Users\\Admin\\Interesting project notebook\\3.pdf']
# CompletedProcess(args=['C:\\Program Files\\wkhtmltopdf\\bin\\wkhtmltopdf.exe', 'https://wkhtmltopdf.org/', 'C:\\Users\\Admin\\Interesting project notebook\\3.pdf'], returncode=0)
