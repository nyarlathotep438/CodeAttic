# %%
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
import sys
import torch

# %%
print("Python 版本:", sys.version)
print("PyTorch 版本:", torch.__version__)
print("CUDA 是否可用:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("PyTorch 编译时的 CUDA 版本:", torch.version.cuda)
    print("当前设备的 CUDA 版本:", torch.cuda.get_device_properties(0).major, ".", torch.cuda.get_device_properties(0).minor)
# Out:
# Python 版本: 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]
# PyTorch 版本: 2.1.0+cu118
# CUDA 是否可用: True
# PyTorch 编译时的 CUDA 版本: 11.8
# 当前设备的 CUDA 版本: 6 . 1
