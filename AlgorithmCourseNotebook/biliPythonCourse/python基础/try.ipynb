# %%
try:
    file = open('eee.txt','r+')
except Exception as e:
    print('there is no file name as eee.txt')
    response = input('do you want to create a new file')
    if response == "y":
        file = open('eee.txt','w')
    else:
        pass
else:
    file.write('无误')
file.close()
