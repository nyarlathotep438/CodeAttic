# %%
a = True
while a:
    b = input('type something')
    if b == '1':
        a = False
    else:
        pass
    
print('finish run')
# Out:
# type something2
# type something3
# type something4
# type something5
# type something6
# type something7
# type something8
# type something
# type something9
# type something0
# type something1
# finish run

# %%
while True:
    b = input('type something')
    if b =='1':
        break
    else:
        pass
    print('still in while')
    
print('finish run')while True:
    b = input('type something')
    if b =='1':
        break
    else:
        pass
    print('still in while')
    
print('finish run')
# Out:
# type something2
# still in while
# type something3
# still in while
# type something4
# still in while
# type something5
# still in while
# type something6
# still in while
# type something7
# still in while
# type something1
# finish run

# %%
while True:
    b = input('type something')
    if b =='2':
        continue
    else:
        pass
    print('still in while')
    
print('finish run')
